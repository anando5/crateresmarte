# %% [markdown]
# Frecuency distribution by the depth topology and diagram circle

# %%
import pandas
import numpy

data = pandas.read_csv("crateres.csv")

print (len(data))
print (len(data.columns))

c1= data["DEPTH_RIMFLOOR_TOPOG"].value_counts(sort=False)
print (c1)

print("percentages for CRATER_ID in the past 12 months,yes=1")
p1 = data["DEPTH_RIMFLOOR_TOPOG"].value_counts(sort=False, normalize=True)
print (p1)

c2= data["DIAM_CIRCLE_IMAGE"].value_counts(sort=False)
print (c2)

p2 = data["DIAM_CIRCLE_IMAGE"].value_counts(sort=False, normalize=True)
print (p2)

ct1 = data.groupby("DEPTH_RIMFLOOR_TOPOG").size()
print (ct1)
# Out:
# 4999
# 10
# 0.00    3773
# 0.75       2
# 0.25       5
# 0.50       1
# 0.59       1
# 0.84       2
# 0.09      27
# 0.34       5
# 0.18       7
# 0.43       4
# 0.96       1
# 0.68       1
# 0.74       1
# 0.02     206
# 0.63       1
# 0.52       2
# 1.77       1
# 0.62       2
# 0.61       1
# 0.11      35
# 0.28       3
# 0.78       2
# 1.20       1
# 0.95       1
# 0.20       5
# 0.45       3
# 1.11       1
# 1.86       1
# 0.29       1
# 0.04      98
#         ...
# 0.03     151
# 0.53       1
# 1.03       1
# 0.38       3
# 0.12      21
# 0.37       4
# 0.71       3
# 1.21       1
# 0.21       8
# 0.46       2
# 1.12       1
# 1.14       1
# 0.30       5
# 0.05      78
# 0.27       2
# 1.05       2
# 0.14      12
# 0.39       1
# 0.44       1
# 0.48       2
# 0.98       1
# 1.98       1
# 0.23       9
# 0.36       1
# 1.41       2
# 0.07      55
# 0.41       2
# 1.32       1
# 0.16      19
# 0.66       1
# Name: DEPTH_RIMFLOOR_TOPOG, dtype: int64
# ...
